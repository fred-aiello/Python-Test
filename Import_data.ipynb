# %% [markdown]
# Enter this code lines in Anaconda prompt script to load the relevant packages (Not to be run in this Notebook)
# pip install yahoo-finance
# pip install quandl

# %%
# import needed modules
# import needed modules

import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# get adjusted closing prices of 5 selected companies with Quandl
quandl.ApiConfig.api_key = 'zcfJ6696mcZScjzsyeta'
selected = ['CNP', 'F', 'WMT', 'GE', 'TSLA']
print (selected)
# Out:
# ['CNP', 'F', 'WMT', 'GE', 'TSLA']

# %%
data = quandl.get_table('WIKI/PRICES', ticker = selected,
                    qopts = { 'columns': ['date', 'ticker', 'adj_close']},
                    date={'gte':'2017-09-01','lte':'2018-01-10'}, paginate=True)
data.head()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-34-540e9e9b744a> in <module>
#       1 data = quandl.get_table('WIKI/PRICES', ticker = selected,
#       2                     qopts = { 'columns': ['date', 'ticker', 'adj_close']},
# ----> 3                     date={'gte':'2017-09-01','lte':'2018-01-10'}, paginate=True)
#       4 data.head()
#
# ~\OneDrive\Documents\Fred\Anaconda\lib\site-packages\quandl\get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# ~\OneDrive\Documents\Fred\Anaconda\lib\site-packages\quandl\model\datatable.py in data(self, **options)
#      26         if not options:
#      27             options = {'params': {}}
# ...

# %%
# reorganise data pulled by setting date as index with
# columns of tickers and their corresponding adjusted prices
clean = data.set_index('date')
table = clean.pivot(columns='ticker')
print table

# %%
#pip install BeautifulSoup4 in the Anaconda prompt invit
from bs4 import BeautifulSoup 
import requests
import csv 
import pandas as pd

# %%
FuturesUrl = 'https://finance.yahoo.com/quote/ES=F'
r= requests.get(FuturesUrl)
print (r)
# Out:
# <Response [200]>

# %%
data=r.text
soup=BeautifulSoup(data)
price=soup.find_all('div')#, attrs={'id':"market-summary"})
print (price)
df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')
# Out:
# [<div id="app"><div class="" data-react-checksum="982788745" data-reactid="1" data-reactroot=""><div data-reactid="2"><div class="render-target-active render-target-default" data-reactid="3" id="render-target-default"><div class="finance US en-US H(100%) uh-search-open_Ovy(h) uh-search-open_H(100vh)" data-reactid="4"><div class="YDC-MainCanvas Bgc($bg-body) Mih(100%)" data-reactid="5" id="YDC-MainCanvas" style="padding-top:54px;margin-bottom:auto;"><div class="YDC-UH lw-nav-open_D(n)" data-reactid="6" id="YDC-UH" style="height:54px;"><div class="YDC-UH-Stack Z(10) End(0) Start(0) T(0) Pos(f) uh-search-open_Pos(a) uh-mobile-nav-open_D(n) lw-nav-open_D(n)" data-reactid="7" id="YDC-UH-Stack"><div data-reactid="8" id="YDC-UH-Stack-Composite"><div data-reactid="9"><div data-locator="subtree-root" id="mrt-node-UH-0-UH"><div data-react-checksum="1967179946" data-reactid="1" data-reactroot="" id="UH-0-UH-Proxy"><div data-reactid="2"><div data-reactid="3"><div class="C(#fff) Fz(13px) H(22px)"
# ...

# %%
#Data change from unix timestamp to date
import datetime
timestamp = datetime.datetime.fromtimestamp(1587735066)
print(timestamp.strftime ('%Y-%m-%d'))  #('%Y-%m-%d %H:%M:%S'))
# Out:
# 2020-04-24

# %%
#Data change from date to unix timestamp
import datetime
date_string = "11/22/2019"
date = datetime.datetime.strptime(date_string, "%m/%d/%Y")
timestamp = datetime.datetime.timestamp(date)

print(timestamp)
# Out:
# 1574377200.0

# %%
prices=[]

FuturesUrl = "https://finance.yahoo.com/quote/ES=F"

r= requests.get(FuturesUrl)
data=r.text
soup=BeautifulSoup(data)

for listing in soup.find_all('div', attrs={'id':"market-summary"}):
for price in listing.find_all('span', attrs={'data-reactid':18}):
prices.append(price.text)

output=pd.DataFrame({"Prices": prices})

#https://query1.finance.yahoo.com/v7/finance/download/%5EFCHI?period1=1556112666&period2=1587735066&interval=1d&events=history
# Out:
#   File "<ipython-input-44-8f837eb45494>", line 10
#     for price in listing.find_all('span', attrs={'data-reactid':18}):
#       ^
# IndentationError: expected an indented block

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['AAPL', 'MSFT', '^GSPC']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2010-01-01'
end_date = '2016-12-31'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader('INPX', 'google', start_date, end_date)

Print (panel_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fda64ec8de5> in <module>
#       7
#       8 # User pandas_reader.data.DataReader to load the desired data. As simple as that.
# ----> 9 panel_data = data.DataReader('INPX', 'google', start_date, end_date)
#      10
#      11 Print (panel_data)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
# Read data
Market_Data=pd.read_csv (r'C:\Users\Hp\OneDrive\Documents\Fred\Trading\EURUSDSPOT_2020-04-17.csv', sep="\t")
Market_Data.head()
df=pd.DataFrame(Market)
df.to_csv(r'C:\Users\Hp\OneDrive\Documents\Fred\Trading\\EURUSD_TEST.csv')
# Out:
#                date    ouv   haut    bas   clot  vol devise
# 0  19/04/2010 00:00  1.349  1.359  1.342  1.349    0    USD
# 1  20/04/2010 00:00  1.349  1.352  1.343  1.344    0    USD
# 2  21/04/2010 00:00  1.344  1.345  1.336  1.339    0    USD
# 3  22/04/2010 00:00  1.339  1.342  1.326  1.329    0    USD
# 4  23/04/2010 00:00  1.327  1.340  1.320  1.337    0    USD
